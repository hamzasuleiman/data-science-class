# %%
import numpy as np
import pandas as pd

# %%
df_rate=pd.read_csv("exchange08112023.csv")
df_rate.head()
# Out:
#                  Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 11/7/2023        US DOLLAR      2023  November    802.8100     803.3100
# 11/7/2023  POUNDS STERLING      2023  November    986.8141     987.4287
# 11/7/2023             EURO      2023  November    856.7588     857.2924
# 11/7/2023      SWISS FRANC      2023  November    890.7245     891.2793
# 11/7/2023              YEN      2023  November      5.3300       5.3334
#
#            Central Rate  Selling Rate
# 11/7/2023      803.8100           NaN
# 11/7/2023      988.0433           NaN
# 11/7/2023      857.8260           NaN
# 11/7/2023      891.8340           NaN
# 11/7/2023        5.3367           NaN

# %%
df_rate.isnull().sum()
# Out:
# Rate Date           0
# Currency            0
# Rate Year           0
# Rate Month          0
# Buying Rate         0
# Central Rate        0
# Selling Rate    53525
# dtype: int64

# %%
df_rate.shape
# Out:
# (53525, 7)

# %%
df_rate.columns
# Out:
# Index(['Rate Date', 'Currency', 'Rate Year', 'Rate Month', 'Buying Rate',
#        'Central Rate', 'Selling Rate'],
#       dtype='object')

# %%
df_rate.reset_index(inplace=True)

# %%
df_rate
# Out:
#             index        Rate Date  Currency Rate Year  Rate Month  \
# 0       11/7/2023        US DOLLAR      2023  November    802.8100
# 1       11/7/2023  POUNDS STERLING      2023  November    986.8141
# 2       11/7/2023             EURO      2023  November    856.7588
# 3       11/7/2023      SWISS FRANC      2023  November    890.7245
# 4       11/7/2023              YEN      2023  November      5.3300
# ...           ...              ...       ...       ...         ...
# 53520  12/10/2001              CFA      2001  December      0.1514
# 53521  12/10/2001             EURO      2001  December     99.3787
# 53522  12/10/2001             WAUA      2001  December    138.8876
# 53523  12/10/2001        US DOLLAR      2001  December    111.8500
# 53524  12/10/2001              YEN      2001  December      0.8881
#
#        Buying Rate  Central Rate  Selling Rate
# 0         803.3100      803.8100           NaN
# 1         987.4287      988.0433           NaN
# ...

# %%
## REBNAMING COLUMNS 
df_rate.rename({"index": "Date","Rate Date":"Currency","Currency": "Rate Year", "Rate Year":"Rate Month", "Rate Month":"Buying Rate", "Buying Rate":"Central Rate", "Central Rate":"Selling Rate","Selling Rate": "NONE"},axis=1,inplace=True)
df_rate.head()
# Out:
#         Date         Currency  Rate Year Rate Month  Buying Rate  \
# 0  11/7/2023        US DOLLAR       2023   November     802.8100
# 1  11/7/2023  POUNDS STERLING       2023   November     986.8141
# 2  11/7/2023             EURO       2023   November     856.7588
# 3  11/7/2023      SWISS FRANC       2023   November     890.7245
# 4  11/7/2023              YEN       2023   November       5.3300
#
#    Central Rate  Selling Rate  NONE
# 0      803.3100      803.8100   NaN
# 1      987.4287      988.0433   NaN
# 2      857.2924      857.8260   NaN
# 3      891.2793      891.8340   NaN
# 4        5.3334        5.3367   NaN

# %%
df_rate.drop({"NONE"},axis=1,inplace=True)

# %%
df_rate
# Out:
#              Date         Currency  Rate Year Rate Month  Buying Rate  \
# 0       11/7/2023        US DOLLAR       2023   November     802.8100
# 1       11/7/2023  POUNDS STERLING       2023   November     986.8141
# 2       11/7/2023             EURO       2023   November     856.7588
# 3       11/7/2023      SWISS FRANC       2023   November     890.7245
# 4       11/7/2023              YEN       2023   November       5.3300
# ...           ...              ...        ...        ...          ...
# 53520  12/10/2001              CFA       2001   December       0.1514
# 53521  12/10/2001             EURO       2001   December      99.3787
# 53522  12/10/2001             WAUA       2001   December     138.8876
# 53523  12/10/2001        US DOLLAR       2001   December     111.8500
# 53524  12/10/2001              YEN       2001   December       0.8881
#
#        Central Rate  Selling Rate
# 0          803.3100      803.8100
# 1          987.4287      988.0433
# ...

# %%
df_rate.isnull().sum()
# Out:
# Date            0
# Currency        0
# Rate Year       0
# Rate Month      0
# Buying Rate     0
# Central Rate    0
# Selling Rate    0
# dtype: int64

# %% [markdown]
# ## date conversion to date_time

# %%
df_rate["Date"]= pd.to_datetime(df_rate["Date"])
df_rate
# Out:
#             Date         Currency  Rate Year Rate Month  Buying Rate  \
# 0     2023-11-07        US DOLLAR       2023   November     802.8100
# 1     2023-11-07  POUNDS STERLING       2023   November     986.8141
# 2     2023-11-07             EURO       2023   November     856.7588
# 3     2023-11-07      SWISS FRANC       2023   November     890.7245
# 4     2023-11-07              YEN       2023   November       5.3300
# ...          ...              ...        ...        ...          ...
# 53520 2001-12-10              CFA       2001   December       0.1514
# 53521 2001-12-10             EURO       2001   December      99.3787
# 53522 2001-12-10             WAUA       2001   December     138.8876
# 53523 2001-12-10        US DOLLAR       2001   December     111.8500
# 53524 2001-12-10              YEN       2001   December       0.8881
#
#        Central Rate  Selling Rate
# 0          803.3100      803.8100
# 1          987.4287      988.0433
# ...

# %%
## CONDITIONAL SELECTION
df_rate[df_rate["Currency"]== "US DOLLAR"]
# Out:
#             Date   Currency  Rate Year Rate Month  Buying Rate  Central Rate  \
# 0     2023-11-07  US DOLLAR       2023   November      802.810       803.310
# 12    2023-11-06  US DOLLAR       2023   November      786.090       786.590
# 24    2023-11-03  US DOLLAR       2023   November      782.674       783.174
# 36    2023-11-02  US DOLLAR       2023   November      806.273       806.773
# 48    2023-11-01  US DOLLAR       2023   November      815.016       815.516
# ...          ...        ...        ...        ...          ...           ...
# 53499 2001-12-14  US DOLLAR       2001   December      112.100       112.600
# 53502 2001-12-13  US DOLLAR       2001   December      111.850       112.350
# 53511 2001-12-12  US DOLLAR       2001   December      111.850       112.350
# 53514 2001-12-11  US DOLLAR       2001   December      111.850       112.350
# 53523 2001-12-10  US DOLLAR       2001   December      111.850       112.350
#
#        Selling Rate
# 0           803.810
# ...

# %%
df_rate[(df_rate["Currency"]== "US DOLLAR") & (df_rate["Rate Month"] == "January")]
# Out:
#             Date   Currency  Rate Year Rate Month  Buying Rate  Central Rate  \
# 2213  2023-01-31  US DOLLAR       2023    January       460.50        461.00
# 2225  2023-01-30  US DOLLAR       2023    January       460.02        460.52
# 2237  2023-01-27  US DOLLAR       2023    January       459.91        460.41
# 2249  2023-01-26  US DOLLAR       2023    January       459.83        460.33
# 2261  2023-01-25  US DOLLAR       2023    January       459.78        460.28
# ...          ...        ...        ...        ...          ...           ...
# 53418 2002-01-08  US DOLLAR       2002    January       112.70        113.20
# 53427 2002-01-07  US DOLLAR       2002    January       112.70        113.20
# 53430 2002-01-04  US DOLLAR       2002    January       112.70        113.20
# 53439 2002-01-03  US DOLLAR       2002    January       112.45        112.95
# 53442 2002-01-02  US DOLLAR       2002    January       112.45        112.95
#
#        Selling Rate
# 2213         461.50
# ...

# %%
 df_rate[(df_rate["Currency"]== "US DOLLAR") &
         (df_rate["Rate Month"] == "January") &
         (df_rate["Date"] >= pd.Timestamp(2001,1,1)) &
         (df_rate["Date"] <= pd.Timestamp(2003,1,31))]
# Out:
#             Date   Currency  Rate Year Rate Month  Buying Rate  Central Rate  \
# 51847 2003-01-31  US DOLLAR       2003    January       126.27        126.77
# 51854 2003-01-30  US DOLLAR       2003    January       126.27        126.77
# 51859 2003-01-29  US DOLLAR       2003    January       126.27        126.77
# 51866 2003-01-28  US DOLLAR       2003    January       126.21        126.71
# 51871 2003-01-27  US DOLLAR       2003    January       126.21        126.71
# 51878 2003-01-24  US DOLLAR       2003    January       126.12        126.62
# 51883 2003-01-23  US DOLLAR       2003    January       126.12        126.62
# 51890 2003-01-22  US DOLLAR       2003    January       126.12        126.62
# 51895 2003-01-21  US DOLLAR       2003    January       126.13        126.63
# 51902 2003-01-20  US DOLLAR       2003    January       126.13        126.63
# 51907 2003-01-17  US DOLLAR       2003    January       126.02        126.52
# ...

# %%
rate_23= df_rate[df_rate['Rate Year'] == 2023]
rate_22 = df_rate[df_rate["Rate Year"] == 2022]
rate_21 = df_rate[df_rate["Rate Year"] == 2021]
rate_20 = df_rate[df_rate["Rate Year"] == 2020]

# %%
## merging tables together 
rate_23.merge(rate_22,how="outer")
# Out:
#            Date            Currency  Rate Year Rate Month  Buying Rate  \
# 0    2023-11-07           US DOLLAR       2023   November     802.8100
# 1    2023-11-07     POUNDS STERLING       2023   November     986.8141
# 2    2023-11-07                EURO       2023   November     856.7588
# 3    2023-11-07         SWISS FRANC       2023   November     890.7245
# 4    2023-11-07                 YEN       2023   November       5.3300
# ...         ...                 ...        ...        ...          ...
# 5364 2022-01-04               RIYAL       2022    January     109.8695
# 5365 2022-01-04  SOUTH AFRICAN RAND       2022    January      25.7516
# 5366 2022-01-04        DANISH KRONA       2022    January      62.5940
# 5367 2022-01-04                 SDR       2022    January     578.1507
# 5368 2021-07-06                EURO       2022       July     484.4799
#
#       Central Rate  Selling Rate
# 0         803.3100      803.8100
# 1         987.4287      988.0433
# ...

# %% [raw]
# ## concatinating the tables together.
# rate_from_2020_to_2023=pd.concat([rate_23,rate_22,rate_21,rate_20])
# rate_from_2020_to_2023

# %%
## saving data in csv
rate_from_2020_to_2023.to_csv("rate_from_2020_to_2023",index=False)

# %%
conda install xlsxwriter
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\USER\anaconda3
#
#   added / updated specs:
#     - xlsxwriter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.12.12 |       haa95532_0         127 KB
#     certifi-2023.11.17         |  py311haa95532_0         160 KB
#     openssl-3.0.12             |       h2bbff1b_0         7.4 MB
#     xlsxwriter-3.1.1           |  py311haa95532_0         320 KB
#     ------------------------------------------------------------
#                                            Total:         8.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   xlsxwriter         pkgs/main/win-64::xlsxwriter-3.1.1-py311haa95532_0
#
# The following packages will be UPDATED:
#
# ...

# %%
## saving data in excel
rate_from_2020_to_2023.to_excel("rate_from_2020_to_2023.xlsx",sheet_name="Rate",index=False)

# %%
with pd.ExcelWriter("Rate.xlsx",engine="xlsxwriter") as writer:
    rate_20.to_excel(writer,sheet_name="Rate 2020",engine="xlsxwriter",index=False)
    rate_21.to_excel(writer,sheet_name="Rate 2021",engine="xlsxwriter",index=False)
    rate_22.to_excel(writer,sheet_name="Rate 2022",engine="xlsxwriter",index=False)
    rate_23.to_excel(writer,sheet_name="Rate 2023",engine="xlsxwriter",index=False)
