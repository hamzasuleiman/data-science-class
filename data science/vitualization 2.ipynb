# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.style.use("ggplot")
sns.displot(x=df["total_bill"],kde=True)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.regplot(x=df["total_bill"],y=df["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=df["total_bill"],y=df["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.countplot(x=df["day"]) ## this is the distribution of categorical  columns
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x=df["day"], hue=df["sex"])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.barplot(x=df["day"],y=df["total_bill"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x=df["day"],y=df["total_bill"], estimator=max)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x=df["day"],y=df["total_bill"], estimator=max,palette="copper_r")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x=df["day"],y=df["total_bill"],estimator=max,pallates="#94035c")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x=df["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(y=df["total_bill"],x=df["day"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df2=sns.load_dataset("flights")
df2.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
## show the distribution btwn tips A perticular day
## show the trend or relationship btwn the tips and total_bill

# %%
sns.barplot(x=df["day"],y=df["tip"],estimator=max)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.regplot(x=df["tip"],y=df["total_bill"])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\USER\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.lineplot(x=df["tip"],y=df["total_bill"])##,estimator=max)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.violinplot(x=df["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(12,8))
ax=sns.barplot(x=df["sex"],y=df["total_bill"],data=df,palette="Blues",estimator=max)
for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x()+ p.get_width()/ 2.,p.get_height()),
                ha="center", va ="baseline", fontsize=10, color="red", xytext=(0,5),
                textcoords="offset points")
plt.title("Day distribution")
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df2=df[["total_bill","tip","size"]]
corr=df2.corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,fmt="0.2g")
# Out:
# <Axes: >
